# %%
print("Note: please enter only any one of the Uniaxial compressive strength or point load index strength and thereby enter the other value as 0")
ucs=float(input("enter the value of the uniaxial compressive strength of the rock smaple in mega pascals"))
psi=float(input("enter the value of the point load index strength of the rock smaplein mega pascals"))
rqd=float(input("enter the rock quality designation (drill core quality) in terms of percentage"))
spd=float(input("enter the spacing of the discontinuities in millimetres"))
discl=float(input("enter the discontinuities length(persistance) in metres"))
aper=float(input("enter the aperture in millimetres"))
print("enter the correspondings numbers based on the roughness,infilling,weathering of the rock:")
rog=int(input("'1' for very rough ,   '2' for rough ,   '3' for slightly rough , '4' for smooth,    '5' slicken sided"))
inf=int(input(" '1' for no filling ,  '2' for hard-filling < 5mm  ,  '3' for hard-filling >5mm , '4' for soft-filling <5mm , '5' for soft filling > 5mm "))
wtg=int(input("'1' for unweathered , '2' for slightly weathered , '3' for moderately weathered , '4' for highly weathered , '5' for decomposed "))
gw=float(input(" enter either the inflow per 10 metre lenght inlit/m else put zero"))
gwc=int(input("enter zero if you know inflow rate  and else select corresponding number '1' for completely dry condition ;'2' for damp ;'3' for wet ; '4' for dripping ; '5' for flowing "))
print("enter the type of developement as per assigned numbers below:")
work=int(input("'1' for mines and tunnels , '2' for foundations , '3' for slopes"))
cond=int(input("enter '1' if the strike is perpendicular to tunnel axis and '2' if strike is parallel to tunnel axis"))
dip1=float(input("enter the dip if it is along the drive direction else enter 0"))
dip2=float(input("enter the dip if it is against the drive direction else enter 0"))
ucsr=0
psir=0
rqdr=0
spdr=0
disclr=0
aperr=0
rogr=0
infr=0
wtgr=0
gwr=0
adjr=0
if(psi==0 and ucs>0):
	if(ucs>=250):
		ucsr=ucsr+15
	elif(ucs>=175 and ucs<250):
		ucsr=ucsr+12+0.04*(ucs-175)
	elif(ucs>=75 and ucs<175):
		ucsr=ucsr+7+0.05*(ucs-75)
	elif(ucs>=37.5 and ucs<75):
		ucsr=ucsr+4+0.08*(ucs-37.5)
	elif(ucs>=15 and ucs<37.5):	
		ucsr=ucsr+2+0.0888888888888*(ucs-15)
	elif(ucs>=3 and ucs<15):
		ucsr=ucsr+1+((ucs-3)/12)
	elif(ucs>=1 and ucs<3):
		ucsr=ucsr+0.5*(ucs-1)

if(ucs==0 and psi>0):
	if(psi>=10):
		psir=psir+15
	elif(psi>=7 and psi<10):
		psir=psir+12+(psi-7)
	elif(psi>=3 and psi<7):
		psir=psir+7+1.25*(psi-3)
	elif(psi>=1.5 and psi<3):
		psir=psir+4+2*(psi-1.5)
	elif(psi>=1 and psi<1.5):
		psir=psir+2+4*(psi-1)
	elif(psi>0 and psi<1):
		print("for this low range of values uniaxial compressive test is preferred over point load index")
if(rqd<100.00000001):
	if(rqd>=82.5 and rqd<=100):
		rqdr=rqdr+17+0.17142857143*(rqd-82.5)
	elif(rqd>=62.5 and rqd<82.5):
		rqdr=rqdr+13+0.2*(rqd-62.5)
	elif(rqd>=37.5 and rqd<37.5):
		rqdr=rqdr+8+0.2*(rqd-37.5)
	elif(rqd>=25 and rqd<37.5):
		rqdr=rqdr+3+0.4*(rqd-25)
	elif(rqd>0 and rqd<25):
		rqdr=rqdr+0.12*(rqd-25)
if(spd>0):
	if(spd>=2000):
		spdr=spdr+20
	elif(spd>=1300 and spd<2000):
		spdr=spdr+15+0.00251635632*(spd-1300)
	elif(spd>=400 and spd<1300):
		spdr=spdr+10+0.005555555556*(spd-400)
	elif(spd>=130 and spd<400):
		spdr=spdr+8+0.0074074074*(spd-130)
	elif(spd>=60 and spd<130):
		spdr=spdr+5+0.04285714286*(spd-60)
	elif(spd>0 and spd<60):
		spdr=spdr+0.08333333333*(spd-60)
if(discl>0 and discl<=20):
	if(discl>0 and discl<=1):
		disclr=disclr+6
	elif(discl>1 and discl<=2):
		disclr=disclr+6-2*(discl-1)
	elif(discl>2 and discl<=6.5):
		disclr=disclr+4-0.444444444444*(discl-2)
	elif(discl>6.5 and discl<=15):
		disclr=disclr+2-0.11764705882*(discl-6.5)
	elif(discl>15 and discl<=20):
		disclr=disclr+1-0.2*(discl-15)
if(aper>=0):
	if(aper==0):
		aperr=aperr+6
	elif(aper>0 and aper<0.1):
		aperr=aperr+6-10*(aper)
	elif(aper>=0.1 and aper<0.55):
		aperr=aperr+5-4.4444444444444*(aper-0.1)
	elif(aper>=0.55 and aper<3):
		aperr=aperr+3-0.81632653061*(aper-0.55)
	elif(aper>=3 and aper<5):
		aperr=aperr+1-0.5*(aper-3)
if((rog>0 and rog<6) and rog%1==0):
	if(rog==1):
		rogr=rogr+6
	elif(rog==2):
		rogr=rogr+5
	elif(rog==3):
		rogr=rogr+3	
	elif(rog==4):
		rogr=rogr+1
	elif(rog==5):
		rogr=rogr+0
if((inf>0 and inf%1==0) and inf<6):
	if(inf==1):
		infr=infr+6
	elif(inf==2):
		infr=infr+4
	elif(inf==3):		
		infr=infr+2		
	elif(infr==4):	
		infr=infr+2
	elif(infr==5):
		infr=infr+0
if((wtg>0 and wtg<6) and wtg%1==0):
	if(wtg==1):
		wtgr=wtgr+6
	elif(wtg==2):
		wtgr=wtgr+5
	elif(wtg==3):
		wtgr=wtgr+3
	elif(wtg==4):
		wtgr=wtgr+1
	elif(wtg==5):
		wtgr=wtgr+0
if(gwc==0):
	if(gw>0 and gw<=0.1):
		gwr=gwr+15-(50*gw)
	elif(gw>0.1 and gw<=0.15):
		gwr=gwr+10-(60*(gw-0.1))
	elif(gw>0.15 and gw<=0.35):
		gwr=gwr+7-(15*(gw-0.15))
	elif(gw>0.35 and gw<=0.5):
		gwr=gwr+4-(26.66666666*(gw-0.35))
	elif(gw>0.5):
		gwr=gwr+0
elif(gwc==1):
	gwr=gwr+15
elif(gwc==2):
	gwr=gwr+10
elif(gwc==3):
	gwr=gwr+7
elif(gwc==4):
	gwr=gwr+4
elif(gwc==5):
	gwr=gwr+0

if(work==1):
	if(cond==1):
		if(dip2==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-5
			elif(dip1>20 and dip1<=45):
				adjr=adjr-2
			elif(dip1>45 and dip<=90):
				adjr=adjr-0
		elif(dip1==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-12
			elif(dip2>20 and dip2<=45):
				adjr=adjr-10
			elif(dip2>45 and dip2<=90):
				adjr=adjr-5
	if(cond==2):
		if(dip2==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-5
			elif(dip1>20 and dip1<=45):
				adjr=adjr-5
			elif(dip1>45 and dip<=90):
				adjr=adjr-12
		elif(dip1==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-5
			elif(dip2>20 and dip2<=45):
				adjr=adjr-5
			elif(dip2>45 and dip2<=90):
				adjr=adjr-12
		
if(work==2):
	if(cond==1):
		if(dip2==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-7
			elif(dip1>20 and dip1<=45):
				adjr=adjr-2
			elif(dip1>45 and dip<=90):
				adjr=adjr-0
		elif(dip1==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-25
			elif(dip2>20 and dip2<=45):
				adjr=adjr-15
			elif(dip2>45 and dip2<=90):
				adjr=adjr-7
	if(cond==2):
		if(dip2==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-7
			elif(dip1>20 and dip1<=45):
				adjr=adjr-7
			elif(dip1>45 and dip<=90):
				adjr=adjr-25
		elif(dip1==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-7
			elif(dip2>20 and dip2<=45):
				adjr=adjr-7
			elif(dip2>45 and dip2<=90):
				adjr=adjr-25
		

if(work==3):
	if(cond==1):
		if(dip2==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-25
			elif(dip1>20 and dip1<=45):
				adjr=adjr-5
			elif(dip1>45 and dip<=90):
				adjr=adjr-0
		elif(dip1==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-85
			elif(dip2>20 and dip2<=45):
				adjr=adjr-50
			elif(dip2>45 and dip2<=90):
				adjr=adjr-25
	if(cond==2):
		if(dip2==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-25
			elif(dip1>20 and dip1<=45):
				adjr=adjr-25
			elif(dip1>45 and dip<=90):
				adjr=adjr-85
		elif(dip1==0):
			if(dip1>0 and dip1<=20):
				adjr=adjr-25
			elif(dip2>20 and dip2<=45):
				adjr=adjr-25
			elif(dip2>45 and dip2<=90):
				adjr=adjr-85
		
rmr=ucsr+psir+rqdr+spdr+disclr+aperr+rogr+infr+wtgr+gwr+adjr
print("The UCS(uniaxial compressive strength) rating of rock is ",ucsr)
print("The PSI(point load index) rating of rock is ",psir)
print("The RQD(rock quality designation) rating of rock is ",rqdr)
print("The SPD(spacing of Discontinuities) rating of rock is ",spdr)
print("The Discontinuity length rating of rock is ",disclr)
print("The Aperture rating of rock is ",aperr)
print("The Roughness rating of rock is ",rogr)
print("The Infilling rating of rock is ",infr)
print("The Weathering rating of rock is ",wtgr)
print("The Ground water rating of rock is ",gwr)
print("The Adjustments Rating based on dip and strike is ",adjr)
print("The finalized Rock-mass Rating is ",rmr)
# Out:
# Note: please enter only any one of the Uniaxial compressive strength or point load index strength and thereby enter the other value as 0
# enter the value of the uniaxial compressive strength of the rock smaple in mega pascals0
# enter the value of the point load index strength of the rock smaplein mega pascals8
# enter the rock quality designation (drill core quality) in terms of percentage70
# enter the spacing of the discontinuities in millimetres300
# enter the discontinuities length(persistance) in metres2
# enter the aperture in millimetres1
# enter the correspondings numbers based on the roughness,infilling,weathering of the rock:
# '1' for very rough ,   '2' for rough ,   '3' for slightly rough , '4' for smooth,    '5' slicken sided3
#  '1' for no filling ,  '2' for hard-filling < 5mm  ,  '3' for hard-filling >5mm , '4' for soft-filling <5mm , '5' for soft filling > 5mm 1
# ...
